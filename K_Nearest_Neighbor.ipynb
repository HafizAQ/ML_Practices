# %% [markdown]
# <a href="https://colab.research.google.com/github/HafizAQ/ML_Practices/blob/main/K_Nearest_Neighbor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 82.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939416 sha256=93ab08beae59113a4b906ad7a7beb876baa9479c374171c4b45822f43a5b07a1
#   Stored in directory: /root/.cache/pip/wheels/2b/83/5c/073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# ...

# %%
from pydataset import data
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
# from sklearn.metrics import confusion_matrix
# Out:
# initiated datasets repo at: /root/.pydataset/

# %%
#choosing dataset: Separating independent and dependent variables
df=data('turnout')
df.head()
X=df[['age','educate','income']]
y=df['vote']
df
# Out:
#        race  age  educate  income  vote
# 1     white   60     14.0  3.3458     1
# 2     white   51     10.0  1.8561     0
# 3     white   24     12.0  0.6304     0
# 4     white   38      8.0  3.4183     1
# 5     white   25     12.0  2.7852     1
# ...     ...  ...      ...     ...   ...
# 1996  white   26     16.0  3.3834     0
# 1997  white   34     12.0  2.9170     1
# 1998  white   51     16.0  7.8949     1
# 1999  white   22     10.0  2.4811     0
# 2000  white   59     10.0  0.5523     0
#
# [2000 rows x 5 columns]

# %%
#Model Development
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
clf=KNeighborsClassifier(7)
clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
#Model Testing
pred=clf.predict(X_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.29      0.36       154
#            1       0.78      0.89      0.84       446
#
#     accuracy                           0.74       600
#    macro avg       0.63      0.59      0.60       600
# weighted avg       0.71      0.74      0.71       600
